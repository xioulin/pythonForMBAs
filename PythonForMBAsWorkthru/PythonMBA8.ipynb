# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df_students=pd.read_pickle('/Users/pkc/Dropbox/Mac/Desktop/Python/python-for-mbas/Part 2/pickles/df_students.pickle')

# %%
df_summarized_orders=pd.read_pickle('/Users/pkc/Dropbox/Mac/Desktop/Python/python-for-mbas/Part 2/pickles/df_summarized_orders.pickle')

# %%
df_orders=pd.read_pickle('/Users/pkc/Dropbox/Mac/Desktop/Python/python-for-mbas/Part 2/Chapter 7/orders.pickle')

# %%
df_orders.head()
# Out:
#    ORDER_ID            DATETIME RESTAURANT_ID      TYPE  DRINKS  COOKIES MAIN
# 0  O1820060 2018-10-11 17:25:50        R10002  IN_STORE     1.0      2.0  NaN  \
# 1  O1011112 2018-05-31 11:35:00        R10003  IN_STORE     0.0      0.0  NaN
# 2   O752854 2018-04-21 18:12:57        R10001  DELIVERY     0.0      2.0   I0
# 3  O2076864 2018-11-17 12:50:52        R10005    PICKUP     1.0      0.0   I0
# 4  O1988898 2018-11-04 18:37:24        R10008  IN_STORE     0.0      0.0   I1
#
#   BASE SIDE_1 SIDE_2 RESTAURANT_NAME                   MAIN_NAME
# 0  NaN    NaN    NaN         Midtown                         NaN
# 1  NaN    NaN    NaN     Bryant Park                         NaN
# 2   I7    I15    I14        Columbia  Charred Chicken Marketbowl
# 3   I5     I9    I12        Flatiron  Charred Chicken Marketbowl
# 4   I7     I9     I9    Williamsburg  Spicy Meatballs Marketbowl

# %%
df_students.groupby('YEAR').AGE.mean()
# Out:
# YEAR
# 1    18.2
# 2    20.0
# 3    20.0
# 4    22.0
# Name: AGE, dtype: float64

# %%
df_students.groupby(['YEAR','HOME_STATE']).AGE.mean()
# Out:
# YEAR  HOME_STATE
# 1     FL            17.5
#       NY            18.5
#       PA            19.0
# 2     HI            19.0
#       OK            21.0
# 3     NY            20.0
# 4     CA            22.0
# Name: AGE, dtype: float64

# %%
df_summarized_orders.head()
# Out:
#     restaurant        date  num_orders  perc_deliv
# 0  Bryant Park  2018-01-01         373         0.0
# 1  Bryant Park  2018-01-02         789         0.0
# 2  Bryant Park  2018-01-03         818         0.0
# 3  Bryant Park  2018-01-04         782         0.0
# 4  Bryant Park  2018-01-05         719         0.0

# %%
df_summarized_orders.groupby('restaurant').num_orders.describe()
# Out:
#                  count         mean         std    min     25%     50%
# restaurant
# Bryant Park      261.0   871.436782  101.617613  373.0   837.0   884.0  \
# Columbia         365.0   687.150685  100.359720  426.0   638.0   723.0
# Flatiron         365.0   772.556164  198.452461  374.0   528.0   854.0
# Midtown          365.0   891.136986  229.107988  200.0   615.0   995.0
# NYU              365.0  1180.438356  122.279493  811.0  1105.0  1220.0
# Upper East Side  355.0   774.650704   69.254111  372.0   728.0   791.0
# Upper West Side  365.0   770.372603   65.760332  603.0   720.0   783.0
# Williamsburg     365.0   862.120548   71.235268  653.0   809.0   878.0
#
#                     75%     max
# restaurant
# Bryant Park       924.0  1055.0
# Columbia          759.0   833.0
# Flatiron          941.0  1026.0
# Midtown          1052.0  1191.0
# NYU              1271.0  1396.0
# Upper East Side   827.0   999.0
# Upper West Side   823.0  1003.0
# Williamsburg      911.0  1146.0

# %%
df_orders.rename(columns={'RESTAURANT_NAME':'NAME'},inplace=True)

# %%
df_orders.head()
# Out:
#    ORDER_ID            DATETIME RESTAURANT_ID      TYPE  DRINKS  COOKIES MAIN
# 0  O1820060 2018-10-11 17:25:50        R10002  IN_STORE     1.0      2.0  NaN  \
# 1  O1011112 2018-05-31 11:35:00        R10003  IN_STORE     0.0      0.0  NaN
# 2   O752854 2018-04-21 18:12:57        R10001  DELIVERY     0.0      2.0   I0
# 3  O2076864 2018-11-17 12:50:52        R10005    PICKUP     1.0      0.0   I0
# 4  O1988898 2018-11-04 18:37:24        R10008  IN_STORE     0.0      0.0   I1
#
#   BASE SIDE_1 SIDE_2          NAME                   MAIN_NAME
# 0  NaN    NaN    NaN       Midtown                         NaN
# 1  NaN    NaN    NaN   Bryant Park                         NaN
# 2   I7    I15    I14      Columbia  Charred Chicken Marketbowl
# 3   I5     I9    I12      Flatiron  Charred Chicken Marketbowl
# 4   I7     I9     I9  Williamsburg  Spicy Meatballs Marketbowl

# %%
df_orders.groupby('NAME').TYPE.value_counts(normalize=True)
# Out:
# NAME             TYPE
# Bryant Park      IN_STORE    0.754002
#                  PICKUP      0.177353
#                  DELIVERY    0.068645
# Columbia         IN_STORE    0.728053
#                  PICKUP      0.171285
#                  DELIVERY    0.100662
# Flatiron         IN_STORE    0.725600
#                  PICKUP      0.172056
#                  DELIVERY    0.102343
# Midtown          IN_STORE    0.753170
#                  PICKUP      0.178024
#                  DELIVERY    0.068805
# NYU              IN_STORE    0.730706
#                  PICKUP      0.168774
#                  DELIVERY    0.100520
# Upper East Side  IN_STORE    0.656743
#                  DELIVERY    0.189381
#                  PICKUP      0.153876
# Upper West Side  IN_STORE    0.656462
#                  DELIVERY    0.189686
#                  PICKUP      0.153852
# Williamsburg     IN_STORE    0.729094
#                  PICKUP      0.169779
#                  DELIVERY    0.101127
# ...

# %%
df_orders.groupby(['NAME','TYPE']).size().unstack()
# Out:
# TYPE             DELIVERY  IN_STORE  PICKUP
# NAME
# Bryant Park         15613    171494   40338
# Columbia            25247    182603   42960
# Flatiron            28859    204607   48517
# Midtown             22380    244980   57905
# NYU                 43310    314832   72718
# Upper East Side     52080    180605   42316
# Upper West Side     53337    184588   43261
# Williamsburg        31822    229427   53425

# %%
monthlyDrinksAve= df_orders.set_index('DATETIME').resample('M').DRINKS.mean().reset_index()

# %%
monthlyDrinksAve
# Out:
#      DATETIME    DRINKS
# 0  2018-01-31  0.075221
# 1  2018-02-28  0.076153
# 2  2018-03-31  0.074170
# 3  2018-04-30  0.081231
# 4  2018-05-31  0.111055
# 5  2018-06-30  0.123110
# 6  2018-07-31  0.135057
# 7  2018-08-31  0.135170
# 8  2018-09-30  0.116516
# 9  2018-10-31  0.092728
# 10 2018-11-30  0.078796
# 11 2018-12-31  0.074387

# %%
plt.plot(monthlyDrinksAve.DATETIME,monthlyDrinksAve.DRINKS,)

# %%
df_orders[df_orders.NAME=='Columbia'].set_index('DATETIME').resample('M').size().plot()
# Out:
# <Axes: xlabel='DATETIME'>
