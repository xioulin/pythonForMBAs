# %%
import pandas as pd

# %%
df_students=pd.read_pickle('/Users/pkc/Dropbox/Mac/Desktop/Python/python-for-mbas/Part 2/pickles/df_students.pickle')

# %%
df_orders=pd.read_pickle('/Users/pkc/Dropbox/Mac/Desktop/Python/python-for-mbas/Part 2/pickles/df_orders.pickle')

# %%
df_summarized_orders=pd.read_pickle('/Users/pkc/Dropbox/Mac/Desktop/Python/python-for-mbas/Part 2/pickles/df_summarized_orders.pickle')

# %%
df_summarized_orders.head()
# Out:
#     restaurant        date  num_orders  perc_deliv
# 0  Bryant Park  2018-01-01         373         0.0
# 1  Bryant Park  2018-01-02         789         0.0
# 2  Bryant Park  2018-01-03         818         0.0
# 3  Bryant Park  2018-01-04         782         0.0
# 4  Bryant Park  2018-01-05         719         0.0

# %%
df_items=pd.read_pickle('/Users/pkc/Dropbox/Mac/Desktop/Python/python-for-mbas/Part 2/pickles/df_items.pickle')

# %%
import matplotlib.pyplot as plt

# %%
df_students.columns= ['FNAME','LNAME','YEAR','HSTATE','AGE','CALC_FINAL','ENG_FINAL']

# %%
df_students.columns
# Out:
# Index(['FNAME', 'LNAME', 'YEAR', 'HSTATE', 'AGE', 'CALC_FINAL', 'ENG_FINAL'], dtype='object')

# %%
df_students.CALC_FINAL.plot(kind='bar')
# Out:
# <Axes: >

# %%
df_students.index = df_students.LNAME

# %%
df_students.CALC_FINAL.plot(kind='bar')
# Out:
# <Axes: xlabel='LNAME'>

# %%
df_students=df_students.reset_index(drop=True)

# %%
df_students.plot(x='LNAME',y='CALC_FINAL',kind='bar')
# Out:
# <Axes: xlabel='LNAME'>

# %%
df_orders.head()
# Out:
#    ORDER_ID            DATETIME RESTAURANT_ID      TYPE  DRINKS  COOKIES MAIN
# 0  O1820060 2018-10-11 17:25:50        R10002  IN_STORE     1.0      2.0  NaN  \
# 1  O1011112 2018-05-31 11:35:00        R10003  IN_STORE     0.0      0.0  NaN
# 2   O752854 2018-04-21 18:12:57        R10001  DELIVERY     0.0      2.0   I0
# 3  O2076864 2018-11-17 12:50:52        R10005    PICKUP     1.0      0.0   I0
# 4  O1988898 2018-11-04 18:37:24        R10008  IN_STORE     0.0      0.0   I1
#
#   BASE SIDE_1 SIDE_2
# 0  NaN    NaN    NaN
# 1  NaN    NaN    NaN
# 2   I7    I15    I14
# 3   I5     I9    I12
# 4   I7     I9     I9

# %%
df_orders.BASE.value_counts()
# Out:
# BASE
# I6    918077
# I7    849049
# I5    508513
# Name: count, dtype: int64

# %%
df_orders.SIDE_2.value_counts(normalize=True)
# Out:
# SIDE_2
# I10    0.218763
# I15    0.216732
# I8     0.138127
# I11    0.101074
# I12    0.090502
# I9     0.088878
# I13    0.077793
# I14    0.068131
# Name: proportion, dtype: float64

# %%
df_orders.TYPE.value_counts(normalize=True).plot(kind='pie')
# Out:
# <Axes: ylabel='proportion'>

# %%
df_orders.RESTAURANT_ID.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='RESTAURANT_ID'>

# %%
df_summarized_orders.head()
# Out:
#     restaurant        date  num_orders  perc_deliv
# 0  Bryant Park  2018-01-01         373         0.0
# 1  Bryant Park  2018-01-02         789         0.0
# 2  Bryant Park  2018-01-03         818         0.0
# 3  Bryant Park  2018-01-04         782         0.0
# 4  Bryant Park  2018-01-05         719         0.0

# %%
df_summarized_orders.columns
# Out:
# Index(['restaurant', 'date', 'num_orders', 'perc_deliv'], dtype='object')

# %%
df_summarized_orders.num_orders.describe()
# Out:
# count    2806.000000
# mean      850.756949
# std       195.490367
# min       200.000000
# 25%       739.000000
# 50%       833.000000
# 75%       949.000000
# max      1396.000000
# Name: num_orders, dtype: float64

# %%
df_summarized_orders.num_orders.plot(kind='box')
# Out:
# <Axes: >

# %%
df_summarized_orders.num_orders.plot(kind='hist',density=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_summarized_orders.perc_deliv.hist(bins=40)
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.jointplot(x='num_orders',y='perc_deliv',data=df_summarized_orders,kind='kde')

# %%
df_orders.DRINKS.mean()
# Out:
# 0.09649031678635939

# %%
df_summarized_orders.restaurant.unique().tolist()
# Out:
# ['Bryant Park',
#  'Columbia',
#  'Flatiron',
#  'Midtown',
#  'NYU',
#  'Upper East Side',
#  'Upper West Side',
#  'Williamsburg']

# %%
df_summarized_orders.num_orders.corr(df_summarized_orders.perc_deliv)
# Out:
# -0.19667409216417953

# %%
(df_orders.DRINKS ==1).head()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# Name: DRINKS, dtype: bool

# %%
df_orders[df_orders.COOKIES >0].shape
# Out:
# (476507, 10)

# %%
(df_orders.COOKIES>0).sum()
# Out:
# 476507

# %%
(df_orders.DRINKS == 2).value_counts(normalize=True)
# Out:
# DRINKS
# False    0.988726
# True     0.011274
# Name: proportion, dtype: float64

# %%
df_summarized_orders.num_orders.head()
# Out:
# 0    373
# 1    789
# 2    818
# 3    782
# 4    719
# Name: num_orders, dtype: int64

# %%
(df_orders.COOKIES+df_orders.DRINKS).head()
# Out:
# 0    3.0
# 1    0.0
# 2    2.0
# 3    1.0
# 4    0.0
# dtype: float64

# %%
df_students.CALC_FINAL.notnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# 8     True
# Name: CALC_FINAL, dtype: bool

# %%
df_students.CALC_FINAL.notnull().sum()
# Out:
# 5

# %%
df_orders[df_orders.COOKIES].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df_orders[df_orders.COOKIES].head()
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/frame.py:3766, in DataFrame.__getitem__(self, key)
#    3764     if is_iterator(key):
#    3765         key = list(key)
# -> 3766     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768 # take() does not accept boolean indexers
#    3769 if getattr(indexer, "dtype", None) == bool:
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
# ...

# %%
df_summarized_orders.head()

# %%
df_summarized_orders.date= pd.to_datetime(df_summarized_orders.date)

# %%
df_summarized_orders.date.dt.day_name().head()

# %%
df_summarized_orders.date.dt.day_name().head()

# %%
#for all(df_summarized_orders.date.dt.day_name()=='Monday')
 #   df_summarized_orders.num_order.mean()

# %%
df_summarized_orders.date.dt.day_name().head()

# %%
df_summarized_orders['isMonday']=(df_summarized_orders.date.dt.day_name()=='Monday')

# %%
df_summarized_orders= df_summarized_orders.drop(columns='isMonday')

# %%
df_summarized_orders['ORDER_VOLUME']='HIGH'

# %%
df_summarized_orders.num_orders[df_summarized_orders.date.dt.day_name()=='Tuesday'].mean()

# %%
df_summarized_orders.loc[df_summarized_orders.num_orders <= 1200, 'ORDER_VOLUME'] = 'MEDIUM'

# %%
df_summarized_orders.loc[df_summarized_orders.num_orders <= 600, 'ORDER_VOLUME'] = 'LOW'

# %%
df_summarized_orders.head()

# %%
df_students.sort_values('HSTATE').sort_values('LNAME')

# %%
df_students[['FNAME','LNAME','AGE']]

# %%
df_summarized_orders.head()

# %%
df_summarized_orders.restaurant.value_counts()

# %%
df_orders[df_orders.COOKIES > 0].shape

# %%
(df_orders.DATETIME.dt.quarter.value_counts().sort_index().plot(kind='line'))

# %%
(df_orders.DATETIME.dt.normalize() == '2018-06-01').sum()

# %%
df_items.ITEM_NAME.str.upper().head()

# %%
(df_summarized_orders.restaurant == 'Bryant Park').sum()

# %%
df_summarized_orders.date = pd.to_datetime(df_summarized_orders.date)

# %%
# the query below finds which values in the df sum or column for date has a datetime name equal to saturday or sunday and finds the sum total

# %%
(((df_summarized_orders.date.dt.day_name()=='Saturday')|(df_summarized_orders.date.dt.day_name()=='Sunday'))|(df_summarized_orders.restaurant == 'Bryant Park')).sum()

# %%
(df_summarized_orders.restaurant == 'Bryant Park').sum()

# %%
df_summarized_orders.num_orders.plot(kind='hist',bins=30)

# %%
df_summarized_orders.head()
